# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# libraries for displaying images
from IPython.display import Image
from IPython.core.display import HTML
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
from pandas import json_normalize
! pip install folium==0.5.0
import folium # plotting library
print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /srv/conda/envs/notebook/lib/python3.7/site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from geopy) (1.52)
# Requirement already satisfied: folium==0.5.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from folium==0.5.0) (2.11.3)
# Requirement already satisfied: branca in /srv/conda/envs/notebook/lib/python3.7/site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.7/site-packages (from folium==0.5.0) (2.25.1)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->folium==0.5.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->folium==0.5.0) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.10)
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'SXVSRVQ0EG2SYNDENYWUZU1XIZ1FQU3NDBKWE1FECIAP0LM4' # your Foursquare ID
CLIENT_SECRET = 'NHTLTQC5QLK5YJKA4WFOTV4AEKABYBVJFAFJ4ZJVO3RT41N1' # your Foursquare Secret
ACCESS_TOKEN = 'E15002NNGJ30TH4WLZSD3TXKQE1H3X1DQC3E5J431LKHAQTL' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SXVSRVQ0EG2SYNDENYWUZU1XIZ1FQU3NDBKWE1FECIAP0LM4
# CLIENT_SECRET:NHTLTQC5QLK5YJKA4WFOTV4AEKABYBVJFAFJ4ZJVO3RT41N1

# %% [markdown]
# <h3>we choose the center of Berlin as our location where we start our tour<h3/>

# %%
address = 'Panoramastraße 1A, 10178 Berlin, Berlin'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 52.520848 13.4084747

# %% [markdown]
# <h3>then we want to search for a nice coffee shop <h3/>

# %%
search_query = 'Coffee'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %% [markdown]
# <h3>we call the foursquare API <h3/>

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION,search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=SXVSRVQ0EG2SYNDENYWUZU1XIZ1FQU3NDBKWE1FECIAP0LM4&client_secret=NHTLTQC5QLK5YJKA4WFOTV4AEKABYBVJFAFJ4ZJVO3RT41N1&ll=52.520848,13.4084747&oauth_token=E15002NNGJ30TH4WLZSD3TXKQE1H3X1DQC3E5J431LKHAQTL&v=20180604&query=Coffee&radius=2000&limit=30'

# %%
results = requests.get(url).json()
#results

# %%
#assign relevant part of JSON to park
park = results['response']['venues']
# tranform venues into a dataframe
dataframe = json_normalize(park)

dataframe.head()
# Out:
#                          id                   name  \
# 0  514453f5e4b071f0e0e0a123         Coffee Fellows
# 1  5d31865fd1b9890007ade245  T2 Breakfast & Coffee
# 2  4ba898d4f964a520c4e139e3          Impala Coffee
# 3  4bf61d1194b2a593a203adee         snack'n coffee
# 4  534926fa11d2adce9850f45b            Coffee Room
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1628082590    False
# 1  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...  v-1628082590    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1628082590    False
# 3  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1628082590    False
# 4  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1628082590    False
#
#         location.address  location.lat  location.lng  \
# 0  Rosa-Luxemburg-Str. 2     52.522656     13.409790
# 1         Litfassplatz 3     52.521933     13.403187
# 2  Schönhauser Allee 173     52.532549     13.412092
# 3         Alexanderplatz     52.521005     13.411965
# 4    Saarbrücker Str. 30     52.529816     13.415447
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 52.52265601136413...                220
# 1  [{'label': 'display', 'lat': 52.521933, 'lng':...                377
# 2  [{'label': 'display', 'lat': 52.532549, 'lng':...               1325
# 3  [{'label': 'display', 'lat': 52.52100527429267...                237
# 4  [{'label': 'display', 'lat': 52.52981574063849...               1104
#
#   location.postalCode location.cc location.neighborhood location.city  \
# 0               10178          DE                 Mitte        Berlin
# 1                 NaN          DE                   NaN        Berlin
# 2               10119          DE                   NaN        Berlin
# 3                 NaN          DE                   NaN        Berlin
# 4               10405          DE                   NaN        Berlin
#
#   location.state location.country  \
# 0         Berlin      Deutschland
# 1         Berlin      Deutschland
# 2         Berlin      Deutschland
# 3         Berlin      Deutschland
# 4         Berlin      Deutschland
#
#                            location.formattedAddress location.crossStreet
# 0              [Rosa-Luxemburg-Str. 2, 10178 Berlin]                  NaN
# 1                           [Litfassplatz 3, Berlin]                  NaN
# 2  [Schönhauser Allee 173 (Schwedter Str.), 10119...       Schwedter Str.
# 3                           [Alexanderplatz, Berlin]                  NaN
# 4                [Saarbrücker Str. 30, 10405 Berlin]                  NaN

# %% [markdown]
# <h3>we clean and filter our data <h3/>

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
            categories_list = row['venue.categories']
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered
# Out:
#                                 name      categories  \
# 0                     Coffee Fellows     Coffee Shop
# 1              T2 Breakfast & Coffee  Breakfast Spot
# 2                      Impala Coffee     Coffee Shop
# 3                     snack'n coffee          Bakery
# 4                        Coffee Room     Coffee Shop
# 5                      Balzac Coffee     Coffee Shop
# 6                     Bonanza Coffee     Coffee Shop
# 7                     Bonanza Coffee     Coffee Shop
# 8                         AMT Coffee     Coffee Shop
# 9                    the coffee shop            Café
# 10                          Coffee I            Café
# 11     Philosoffee Pop-Up Coffee Bar     Coffee Shop
# 12                  Meyerbeer Coffee     Coffee Shop
# 13               Bonaverde Coffee AG            Café
# 14                      Melis Coffee            Café
# 15                         BEN RAHIM     Coffee Shop
# 16                    Coffee Fellows     Coffee Shop
# 17                     Coffee Orange            Café
# 18                     Coffee Circle     Coffee Shop
# 19                  Concierge Coffee     Coffee Shop
# 20               Coffee Fellows GmbH            Café
# 21                     Back & Coffee            Café
# 22               Coffee Fellows GmbH            Café
# 23            Breakfast & Coffee Inn     Coffee Shop
# 24                      Coffee Point          Bakery
# 25  Caramello - Ice & Coffee & Pizza  Ice Cream Shop
# 26                     Berlin Coffee     Coffee Shop
# 27                     Zappas Coffee     Coffee Shop
# 28                       Coffee Shop          Bakery
# 29                   Coffee Shop Inn     Coffee Shop
#
#                      address        lat        lng  \
# 0      Rosa-Luxemburg-Str. 2  52.522656  13.409790
# 1             Litfassplatz 3  52.521933  13.403187
# 2      Schönhauser Allee 173  52.532549  13.412092
# 3             Alexanderplatz  52.521005  13.411965
# 4        Saarbrücker Str. 30  52.529816  13.415447
# 5     Karl-Liebknecht-Str. 5  52.519681  13.403687
# 6               Jägerstr. 58  52.514034  13.390665
# 7         Oderberger Str. 35  52.539993  13.405530
# 8           Hackescher Markt  52.523158  13.403127
# 9        Werderscher Markt 1  52.515441  13.397738
# 10          Brückenstr. 5-6a  52.513210  13.417482
# 11       Rosenthaler Str. 66  52.528383  13.402483
# 12     Universitätsstr. 2/3a  52.520016  13.392046
# 13       Schröderstraße 11/2  52.529796  13.402503
# 14      Am Friedrichshain 35  52.528184  13.424416
# 15             Sophienstr. 7  52.525168  13.401928
# 16        Neue Grünstraße 41  52.520379  13.411025
# 17              Knaackstr. 8  52.534159  13.419821
# 18  Rosa-Luxemburg-Straße 19  52.525339  13.410462
# 19                       NaN  52.509781  13.422335
# 20           Rathausstraße 6  52.520716  13.410576
# 21                       NaN  52.509263  13.392370
# 22   Rosa-Luxemburg-Straße 2  52.522932  13.409139
# 23      Karl-Liebknecht-Str.  52.523102  13.411780
# 24         Friedrichstr. 224  52.504472  13.390868
# 25           Hufelandstr. 14  52.532172  13.431427
# 26                       NaN  52.521070  13.411037
# 27            Panoramastr. 2  52.521518  13.410426
# 28                       NaN  52.523166  13.411686
# 29          Alexanderplatz 7  52.523385  13.411916
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 52.52265601136413...       220      10178
# 1   [{'label': 'display', 'lat': 52.521933, 'lng':...       377        NaN
# 2   [{'label': 'display', 'lat': 52.532549, 'lng':...      1325      10119
# 3   [{'label': 'display', 'lat': 52.52100527429267...       237        NaN
# 4   [{'label': 'display', 'lat': 52.52981574063849...      1104      10405
# 5   [{'label': 'display', 'lat': 52.51968106379066...       349      10178
# 6   [{'label': 'display', 'lat': 52.514034, 'lng':...      1425      10117
# 7   [{'label': 'display', 'lat': 52.53999265350801...      2140      10435
# 8   [{'label': 'display', 'lat': 52.52315836250000...       444      10178
# 9   [{'label': 'display', 'lat': 52.51544126096473...       944      10117
# 10  [{'label': 'display', 'lat': 52.51321017163587...      1046      10179
# 11  [{'label': 'display', 'lat': 52.52838250543396...       931      10119
# 12  [{'label': 'display', 'lat': 52.52001571120682...      1116      10117
# 13  [{'label': 'display', 'lat': 52.529796, 'lng':...      1075      10115
# 14  [{'label': 'display', 'lat': 52.52818381278111...      1353      10407
# 15  [{'label': 'display', 'lat': 52.52516811272114...       654      10178
# 16  [{'label': 'display', 'lat': 52.520379, 'lng':...       180      10179
# 17  [{'label': 'display', 'lat': 52.53415859518849...      1669      10405
# 18  [{'label': 'display', 'lat': 52.525339, 'lng':...       517      10178
# 19  [{'label': 'display', 'lat': 52.509781, 'lng':...      1548        NaN
# 20  [{'label': 'display', 'lat': 52.5207158, 'lng'...       143      10178
# 21  [{'label': 'display', 'lat': 52.50926303750872...      1689        NaN
# 22  [{'label': 'display', 'lat': 52.522932, 'lng':...       236      10178
# 23  [{'label': 'display', 'lat': 52.52310158075973...       336        NaN
# 24  [{'label': 'display', 'lat': 52.50447189450626...      2178      10969
# 25  [{'label': 'display', 'lat': 52.53217195726009...      2001      10407
# 26  [{'label': 'display', 'lat': 52.52107009897175...       175        NaN
# 27  [{'label': 'display', 'lat': 52.52151767106789...       151      10178
# 28  [{'label': 'display', 'lat': 52.52316602829705...       337        NaN
# 29  [{'label': 'display', 'lat': 52.52338491572048...       366      10178
#
#     cc             neighborhood    city   state      country  \
# 0   DE                    Mitte  Berlin  Berlin  Deutschland
# 1   DE                      NaN  Berlin  Berlin  Deutschland
# 2   DE                      NaN  Berlin  Berlin  Deutschland
# 3   DE                      NaN  Berlin  Berlin  Deutschland
# 4   DE                      NaN  Berlin  Berlin  Deutschland
# 5   DE                      NaN  Berlin  Berlin  Deutschland
# 6   DE                      NaN  Berlin  Berlin  Deutschland
# 7   DE                      NaN  Berlin  Berlin  Deutschland
# 8   DE                      NaN  Berlin  Berlin  Deutschland
# 9   DE                      NaN  Berlin  Berlin  Deutschland
# 10  DE                      NaN  Berlin  Berlin  Deutschland
# 11  DE                      NaN  Berlin  Berlin  Deutschland
# 12  DE                      NaN  Berlin  Berlin  Deutschland
# 13  DE                    Mitte  Berlin  Berlin  Deutschland
# 14  DE  Greifswalder Straße-Süd  Berlin  Berlin  Deutschland
# 15  DE                      NaN  Berlin  Berlin  Deutschland
# 16  DE                      NaN  Berlin  Berlin  Deutschland
# 17  DE                      NaN  Berlin  Berlin  Deutschland
# 18  DE                      NaN  Berlin  Berlin  Deutschland
# 19  DE                      NaN  Berlin  Berlin  Deutschland
# 20  DE                      NaN  Berlin  Berlin  Deutschland
# 21  DE                      NaN  Berlin  Berlin  Deutschland
# 22  DE                      NaN  Berlin  Berlin  Deutschland
# 23  DE                      NaN  Berlin  Berlin  Deutschland
# 24  DE                      NaN  Berlin  Berlin  Deutschland
# 25  DE                      NaN  Berlin  Berlin  Deutschland
# 26  DE                      NaN  Berlin  Berlin  Deutschland
# 27  DE                      NaN  Berlin  Berlin  Deutschland
# 28  DE                      NaN  Berlin  Berlin  Deutschland
# 29  DE                      NaN  Berlin  Berlin  Deutschland
#
#                                      formattedAddress            crossStreet  \
# 0               [Rosa-Luxemburg-Str. 2, 10178 Berlin]                    NaN
# 1                            [Litfassplatz 3, Berlin]                    NaN
# 2   [Schönhauser Allee 173 (Schwedter Str.), 10119...         Schwedter Str.
# 3                            [Alexanderplatz, Berlin]                    NaN
# 4                 [Saarbrücker Str. 30, 10405 Berlin]                    NaN
# 5   [Karl-Liebknecht-Str. 5 (Spandauer Str.), 1017...         Spandauer Str.
# 6                        [Jägerstr. 58, 10117 Berlin]                    NaN
# 7                  [Oderberger Str. 35, 10435 Berlin]                    NaN
# 8      [Hackescher Markt (S-Bahnbögen), 10178 Berlin]            S-Bahnbögen
# 9   [Werderscher Markt 1 (im Auswärtigen Amt), 101...     im Auswärtigen Amt
# 10                   [Brückenstr. 5-6a, 10179 Berlin]                    NaN
# 11                [Rosenthaler Str. 66, 10119 Berlin]                    NaN
# 12  [Universitätsstr. 2/3a (Georgenstr.), 10117 Be...            Georgenstr.
# 13                [Schröderstraße 11/2, 10115 Berlin]                    NaN
# 14               [Am Friedrichshain 35, 10407 Berlin]                    NaN
# 15                      [Sophienstr. 7, 10178 Berlin]                    NaN
# 16                 [Neue Grünstraße 41, 10179 Berlin]                    NaN
# 17                       [Knaackstr. 8, 10405 Berlin]                    NaN
# 18           [Rosa-Luxemburg-Straße 19, 10178 Berlin]                    NaN
# 19                                           [Berlin]                    NaN
# 20                    [Rathausstraße 6, 10178 Berlin]                    NaN
# 21                                           [Berlin]                    NaN
# 22            [Rosa-Luxemburg-Straße 2, 10178 Berlin]                    NaN
# 23                     [Karl-Liebknecht-Str., Berlin]                    NaN
# 24                  [Friedrichstr. 224, 10969 Berlin]                    NaN
# 25      [Hufelandstr. 14 (Esmarchstr.), 10407 Berlin]            Esmarchstr.
# 26                                           [Berlin]                    NaN
# 27  [Panoramastr. 2 (unter dem Fernsehturn), 10178...  unter dem Fernsehturn
# 28                                           [Berlin]                    NaN
# 29  [Alexanderplatz 7 (Karl-Liebknecht-Str.), 1017...   Karl-Liebknecht-Str.
#
#                           id
# 0   514453f5e4b071f0e0e0a123
# 1   5d31865fd1b9890007ade245
# 2   4ba898d4f964a520c4e139e3
# 3   4bf61d1194b2a593a203adee
# 4   534926fa11d2adce9850f45b
# 5   4b0e18d0f964a520f05423e3
# 6   5eca85b8f2870e000801509b
# 7   4af28ef8f964a520eae721e3
# 8   4b11338ff964a520d57823e3
# 9   4e4a6397c65bab12516c3dd6
# 10  4bc5a3edccbcef3b47b9e6d2
# 11  5b6840e2cb3fd20039a5497d
# 12  4b1d2d5ef964a520950c24e3
# 13  53c81eb2498e04400a4abf29
# 14  4d91ab991e8788bfa5724a05
# 15  5513bfb5498ea118a7b91102
# 16  5c94c9b72db4a9002c27ee75
# 17  4bd403c3046076b0b0487771
# 18  607ad2d5cb0997113f28f11a
# 19  5d595653ab9ab00008d9a7f5
# 20  5f92ac117527613638db9949
# 21  4dd4d605183859a589ab9908
# 22  5f92ac59aecd7170c221eee2
# 23  576f064d498e4365817908a3
# 24  4dcce06b1f6eb12270538862
# 25  4e09b829b61c60b04553fb41
# 26  5415a2bb498ec356dccd2a38
# 27  510d05ece4b033507fd69bcb
# 28  50c06d21e4b0a80fdbec24cc
# 29  4f368ce7e4b039c3c17bf993

# %% [markdown]
# <h3>then we use the Folium to visualize our map<h3/>

# %% [markdown]
# <h3>we will mark the center of Berlin (Alexander platz) with red circle and the coffee shops arround with blue circle <h3/>

# %%
berlin_map = folium.Map(location=[latitude, longitude], zoom_start=13) #generate map centred around the Conrad Hotel
# add a red circle marker to represent the Alexander platz the center of berlin
folium.CircleMarker([latitude, longitude],radius=10,color='red',popup='Alexander platz',fill = True,fill_color = 'red',fill_opacity = 0.6).add_to(berlin_map)
# add the coffee shop  as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker([lat, lng],radius=5,color='blue',popup=label,fill = True,fill_color='blue',fill_opacity=0.6).add_to(berlin_map)
# display map
berlin_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_56f884a4f457492fbbf5e068b91cde35%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_56f884a4f457492fbbf5e068b91cde35%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_56f884a4f457492fbbf5e068b91cde35%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_56f884a4f457492fbbf5e068b91cde35%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B52.520848%2C13.4084747%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# <h3>we are interrested in one of the coffee shops and we want to see the rates <h3/>

# %%
venue_id = '514453f5e4b071f0e0e0a123' # ID of coffee
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id,CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/514453f5e4b071f0e0e0a123?client_id=SXVSRVQ0EG2SYNDENYWUZU1XIZ1FQU3NDBKWE1FECIAP0LM4&client_secret=NHTLTQC5QLK5YJKA4WFOTV4AEKABYBVJFAFJ4ZJVO3RT41N1&oauth_token=E15002NNGJ30TH4WLZSD3TXKQE1H3X1DQC3E5J431LKHAQTL&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'like', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto', 'colors'])
# {'id': '514453f5e4b071f0e0e0a123',
#  'name': 'Coffee Fellows',
#  'contact': {'phone': '03027891945',
#   'formattedPhone': '030 27891945',
#   'facebook': '313849360475',
#   'facebookName': 'Coffee Fellows'},
#  'location': {'address': 'Rosa-Luxemburg-Str. 2',
#   'lat': 52.52265601136413,
#   'lng': 13.409790005427109,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 52.52265601136413,
#     'lng': 13.409790005427109}],
#   'postalCode': '10178',
#   'cc': 'DE',
#   'neighborhood': 'Mitte',
#   'city': 'Berlin',
#   'state': 'Berlin',
#   'country': 'Deutschland',
#   'formattedAddress': ['Rosa-Luxemburg-Str. 2', '10178 Berlin']},
#  'canonicalUrl': 'https://foursquare.com/v/coffee-fellows/514453f5e4b071f0e0e0a123',
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'shortName': 'Coffee Shop',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 87},
#  'url': 'http://coffee-fellows.de',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '€'},
#  'likes': {'count': 232,
#   'groups': [{'type': 'others', 'count': 232, 'items': []}],
#   'summary': '232 Likes'},
#  'like': False,
#  'dislike': False,
#  'ok': False,
#  'rating': 5.7,
#  'ratingColor': 'FF9600',
#  'ratingSignals': 461,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 240,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 240,
#     'items': [{'id': '51c83052498e0c20f655f449',
#       'createdAt': 1372074066,
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/36334563_mHsfOvvTp2ETnNQumxEwYAfRRMzslV2AXNRPds3ZpjM.jpg',
#       'width': 720,
#       'height': 720,
#       'user': {'id': '36334563',
#        'firstName': 'Maria',
#        'lastName': 'Marieta',
#        'gender': 'female',
#        'countryCode': 'ES',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/O2FASQL5N5OEKR32.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': 'Feel at Home - Mit bestem Kaffee, frisch zubereiteten Bagels und süßen Naschereien verwöhnt Coffee Fellows seine Gäste in gemütlichem Ambiente und sorgt somit für eine kleine Auszeit vom Alltag',
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1363432437,
#  'tips': {'count': 87,
#   'groups': [{'type': 'following',
#     'name': 'Tips from people you follow',
#     'count': 0,
#     'items': []},
#    {'type': 'others',
#     'name': 'All tips',
#     'count': 87,
#     'items': [{'id': '518d1156498ef25064937309',
#       'createdAt': 1368199510,
#       'text': 'Sehr unfreundliches Personal, kaum Vorrat vorhanden. Vanille Latte: kein vanilla. Von ca 5 angebotenen bagel Sorten nur 2 verfügbar. Nur Barzahlung möglich, kein Schild vorhanden. Bagels lecker',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/518d1156498ef25064937309',
#       'lang': 'de',
#       'likes': {'count': 5,
#        'groups': [{'type': 'others',
#          'count': 5,
#          'items': [{'id': '1187415',
#            'firstName': 'Robin Food',
#            'gender': 'male',
#            'countryCode': 'IT',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/1187415_4PYZUBnc_2DFBYZIqp_hTSlqZpycDyrucCbaHtJIWHfq79Pd33a7WfrBC0MtcZYDwR-xi018T.jpg'}},
#           {'id': '610957',
#            'firstName': 'Data',
#            'lastName': 'Rusty',
#            'gender': 'male',
#            'countryCode': 'DE',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/J2KR0X13ASRCTHHO.jpg'}},
#           {'id': '4101707',
#            'firstName': 'Jessie',
#            'lastName': 'Mielke',
#            'gender': 'female',
#            'countryCode': 'US',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/UVSHOARWCPH5DWCR.jpg'}},
#           {'id': '50671640',
#            'firstName': 'Liylo',
#            'lastName': 'Mcwilliams',
#            'gender': 'female',
#            'countryCode': 'US',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/0EM513ALSHXEXTU0.jpg'}}]}],
#        'summary': '5 likes'},
#       'like': False,
#       'logView': True,
#       'agreeCount': 4,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '4101707',
#        'firstName': 'Jessie',
#        'lastName': 'Mielke',
#        'gender': 'female',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/UVSHOARWCPH5DWCR.jpg'}},
#       'authorInteractionType': 'disliked'}]}]},
#  'shortUrl': 'http://4sq.com/Xf8waP',
#  'timeZone': 'Europe/Berlin',
#  'listed': {'count': 36,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 36,
#     'items': [{'id': '50bf1b43e4b0fb901fe1a991',
#       'name': 'Berlin',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '39275854',
#        'firstName': 'Michael',
#        'lastName': 'Puschmann',
#        'gender': 'male',
#        'countryCode': 'GR',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/-O43QAROT4GEXZX5X.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/39275854/list/berlin',
#       'canonicalUrl': 'https://foursquare.com/user/39275854/list/berlin',
#       'createdAt': 1354701635,
#       'updatedAt': 1565142214,
#       'photo': {'id': '4fc778ace4b0785353cd227b',
#        'createdAt': 1338472620,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/5SOZnxGoPdGCQjCKRRmAnzQa84KNWvoDJuiQXe07oec.jpg',
#        'width': 537,
#        'height': 720,
#        'user': {'id': '85029',
#         'firstName': 'localr',
#         'gender': 'male',
#         'countryCode': 'DE',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/85029_Q-SRrK0u_mK-lIsYYfGOtBbGRrZDNQ3aDSXHLnY0ZduacR-cuTIdr3Mc9xnQNefZoY6NVGYwU.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 4},
#       'listItems': {'count': 195,
#        'items': [{'id': 'v514453f5e4b071f0e0e0a123',
#          'createdAt': 1373017435}]}},
#      {'id': '542c9738498e38bdef5fc8db',
#       'name': 'Berlin',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '4996',
#        'firstName': 'Michelle',
#        'lastName': 'Lee',
#        'gender': 'female',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/4996_cDwpw6HH_plCwg7d9Z6AUW9_csU8urlB9G_fOLrWcr-mth08Ud-viUSSCj96ZDggZgyooLcV8'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/mlee525/list/berlin',
#       'canonicalUrl': 'https://foursquare.com/mlee525/list/berlin',
#       'createdAt': 1412208440,
#       'updatedAt': 1424872529,
#       'photo': {'id': '542b6088498edb190fe4c3b9',
#        'createdAt': 1412128904,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/4996_-tqIUEe5i4aNAysliLaYsADcqxBbbF3nRnpDMW9Vtns.jpg',
#        'width': 640,
#        'height': 640,
#        'user': {'id': '4996',
#         'firstName': 'Michelle',
#         'lastName': 'Lee',
#         'gender': 'female',
#         'countryCode': 'US',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/4996_cDwpw6HH_plCwg7d9Z6AUW9_csU8urlB9G_fOLrWcr-mth08Ud-viUSSCj96ZDggZgyooLcV8'}},
#        'visibility': 'public'},
#       'followers': {'count': 3},
#       'listItems': {'count': 58,
#        'items': [{'id': 'v514453f5e4b071f0e0e0a123',
#          'createdAt': 1412208970,
#          'photo': {'id': '51c83052498e0c20f655f449',
#           'createdAt': 1372074066,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/36334563_mHsfOvvTp2ETnNQumxEwYAfRRMzslV2AXNRPds3ZpjM.jpg',
#           'width': 720,
#           'height': 720,
#           'user': {'id': '36334563',
#            'firstName': 'Maria',
#            'lastName': 'Marieta',
#            'gender': 'female',
#            'countryCode': 'ES',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/O2FASQL5N5OEKR32.jpg'}},
#           'visibility': 'public'}}]}}]}]},
#  'hours': {'status': 'Open until 10:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–10:00 PM'}],
#     'segments': []}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '8:00 AM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '8:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '8:00 AM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '9:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '9:00 AM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Mon–Tue',
#     'open': [{'renderedTime': '8:00 AM–7:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Open until 10:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 10:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–10:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4e4a5acffa76a0c058ce80c9',
#   'name': 'Grenanderhaus',
#   'location': {'address': 'Rosa-Luxemburg-Str. 2',
#    'lat': 52.522932051863044,
#    'lng': 13.409199714660645,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 52.522932051863044,
#      'lng': 13.409199714660645}],
#    'postalCode': '10178',
#    'cc': 'DE',
#    'city': 'Berlin',
#    'state': 'Berlin',
#    'country': 'Deutschland',
#    'formattedAddress': ['Rosa-Luxemburg-Str. 2', '10178 Berlin']},
#   'categories': [{'id': '4bf58dd8d48988d124941735',
#     'name': 'Office',
#     'pluralName': 'Offices',
#     'shortName': 'Office',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': 'Grenanderhaus',
#    'lang': 'DE',
#    'id': '4e4a5acffa76a0c058ce80c9',
#    'canonicalUrl': 'https://foursquare.com/v/grenanderhaus/4e4a5acffa76a0c058ce80c9'}],
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '€€',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '€€', 'priceTier': 2}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 5,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express & MasterCard)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Free Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Free'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Brunch',
#     'count': 8,
#     'items': [{'displayName': 'Brunch', 'displayValue': 'Brunch'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Beer & Full Bar',
#     'count': 5,
#     'items': [{'displayName': 'Beer', 'displayValue': 'Beer'},
#      {'displayName': 'Full Bar', 'displayValue': 'Full Bar'}]},
#    {'type': 'restroom',
#     'name': 'Restroom',
#     'summary': 'Restroom',
#     'count': 1,
#     'items': [{'displayName': 'Restroom', 'displayValue': 'Yes'}]},
#    {'type': 'wheelchairAccessible',
#     'name': 'Wheelchair Accessible',
#     'summary': 'Wheelchair Accessible',
#     'count': 1,
#     'items': [{'displayName': 'Wheelchair Accessible',
#       'displayValue': 'Yes'}]},
#    {'type': 'tvs',
#     'name': 'TVs',
#     'summary': 'TVs',
#     'count': 1,
#     'items': [{'displayName': 'TVs', 'displayValue': 'Yes'}]}]},
#  'bestPhoto': {'id': '51c83052498e0c20f655f449',
#   'createdAt': 1372074066,
#   'source': {'name': 'Foursquare for Android',
#    'url': 'https://foursquare.com/download/#/android'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/36334563_mHsfOvvTp2ETnNQumxEwYAfRRMzslV2AXNRPds3ZpjM.jpg',
#   'width': 720,
#   'height': 720,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '51c83052498e0c20f655f449',
#    'value': -8353640},
#   'highlightTextColor': {'photoId': '51c83052498e0c20f655f449',
#    'value': -16777216},
#   'algoVersion': 3}}

# %%
#to see the general rates
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.7

# %% [markdown]
# <h3>to see the tips<h3/>

# %%
result['response']['venue']['tips']['count']
# Out:
# 87

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}&limit={}'.format(venue_id,CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION, limit)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '610a94a6d41db438494872b6'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'tips': {'count': 55,
#    'items': [{'id': '55f34b24498e1b1bb399cddd',
#      'createdAt': 1442007844,
#      'text': 'This place was amazing! I wish I found it before that last day of my visit to Berlin. Excellent place for breakfast, great range of options (plenty of vegetarian options too), awesome friendly staff!!',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/55f34b24498e1b1bb399cddd',
#      'likes': {'count': 0, 'groups': []},
#      'like': False,
#      'logView': True,
#      'agreeCount': 1,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '126697992',
#       'firstName': 'Stan',
#       'lastName': 'Darsh',
#       'gender': 'none',
#       'countryCode': 'AU',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/blank_boy.png',
#        'default': True}},
#      'authorInteractionType': 'liked'}]}}}

# %%
tips = results['response']['tips']['items']
tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'likes', 'like', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %% [markdown]
# <h3>and here we can read the top tip for the coffee shop<h3/>

# %%
pd.set_option('display.max_colwidth', None)
tips_df = json_normalize(tips) # json normalize tips
# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]
# display tips
tips_filtered.reindex()
# Out:
#                                                                                                                                                                                                        text  \
# 0  This place was amazing! I wish I found it before that last day of my visit to Berlin. Excellent place for breakfast, great range of options (plenty of vegetarian options too), awesome friendly staff!!
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0           1              0  55f34b24498e1b1bb399cddd           Stan
#
#   user.lastName    user.id
# 0         Darsh  126697992

# %% [markdown]
# <h3>and after drinking our coffee we are interrested in the area of the coffee shop and we want to explore it <h3/>

# %%
latitude =52.52265601136413
longitude =13.409790005427109

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=SXVSRVQ0EG2SYNDENYWUZU1XIZ1FQU3NDBKWE1FECIAP0LM4&client_secret=NHTLTQC5QLK5YJKA4WFOTV4AEKABYBVJFAFJ4ZJVO3RT41N1&ll=52.52265601136413,13.409790005427109&v=20180604&radius=2000&limit=30'

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around place.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around place.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4bb8541f1261d13a118fe898',
#   'name': 'Fat Tire Bike Tours',
#   'location': {'address': 'Panoramastr. 1a',
#    'lat': 52.521232885960515,
#    'lng': 13.409109598118372,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 52.521232885960515,
#      'lng': 13.409109598118372}],
#    'distance': 164,
#    'postalCode': '10178',
#    'cc': 'DE',
#    'city': 'Berlin',
#    'state': 'Berlin',
#    'country': 'Deutschland',
#    'formattedAddress': ['Panoramastr. 1a', '10178 Berlin', 'Deutschland']},
#   'categories': [{'id': '4e4c9077bd41f78e849722f9',
#     'name': 'Bike Rental / Bike Share',
#     'pluralName': 'Bike Rentals / Bike Shares',
#     'shortName': 'Bike',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4bb8541f1261d13a118fe898-0'}

# %% [markdown]
# <h3>and here again we clean<h3/>

# %%
dataframe = json_normalize(items) # flatten JSON
# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]
# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)
# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]
dataframe_filtered.head(10)
# Out:
#                     name                categories                  address  \
# 0    Fat Tire Bike Tours  Bike Rental / Bike Share          Panoramastr. 1a
# 1                19grams               Coffee Shop  Karl-Liebknecht-Str. 13
# 2                 MYKITA              Optical Shop  Rosa-Luxemburg-Straße 6
# 3           Flying Tiger                 Gift Shop         Alexanderplatz 8
# 4       Father Carpenter               Coffee Shop              Münzstr. 21
# 5           Klub Kitchen                    Bistro        Almstadtstr. 9-11
# 6  Lebensmittel in Mitte         German Restaurant               Rochstr. 2
# 7                 Shiori       Japanese Restaurant       Max-Beer-Straße 13
# 8               dolores*             Burrito Place    Rosa-Luxemburg-Str. 7
# 9                   LUSH            Cosmetics Shop            Rathausstr. 5
#
#          lat        lng  \
# 0  52.521233  13.409110
# 1  52.522736  13.407344
# 2  52.523520  13.409480
# 3  52.522437  13.412612
# 4  52.524469  13.406614
# 5  52.524849  13.408988
# 6  52.524150  13.407660
# 7  52.525501  13.408275
# 8  52.523736  13.409249
# 9  52.519844  13.410409
#
#                                                                  labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 52.521232885960515, 'lng': 13.409109598118372}]
# 1   [{'label': 'display', 'lat': 52.52273621459739, 'lng': 13.407343626022339}]
# 2                      [{'label': 'display', 'lat': 52.52352, 'lng': 13.40948}]
# 3   [{'label': 'display', 'lat': 52.52243722587935, 'lng': 13.412612279052135}]
# 4   [{'label': 'display', 'lat': 52.52446934407154, 'lng': 13.406614065170288}]
# 5                    [{'label': 'display', 'lat': 52.524849, 'lng': 13.408988}]
# 6   [{'label': 'display', 'lat': 52.52415016934014, 'lng': 13.407659595853865}]
# 7     [{'label': 'display', 'lat': 52.5255006388942, 'lng': 13.40827536421529}]
# 8                    [{'label': 'display', 'lat': 52.523736, 'lng': 13.409249}]
# 9   [{'label': 'display', 'lat': 52.51984357496295, 'lng': 13.410409304434047}]
#
#    distance postalCode  cc    city   state      country  \
# 0       164      10178  DE  Berlin  Berlin  Deutschland
# 1       165      10178  DE  Berlin  Berlin  Deutschland
# 2        98      10178  DE  Berlin  Berlin  Deutschland
# 3       192      10178  DE  Berlin  Berlin  Deutschland
# 4       294      10178  DE  Berlin  Berlin  Deutschland
# 5       250      10119  DE  Berlin  Berlin  Deutschland
# 6       220      10178  DE  Berlin  Berlin  Deutschland
# 7       332      10119  DE  Berlin  Berlin  Deutschland
# 8       125      10178  DE  Berlin  Berlin  Deutschland
# 9       315      10178  DE  Berlin  Berlin  Deutschland
#
#                                                   formattedAddress  \
# 0                     [Panoramastr. 1a, 10178 Berlin, Deutschland]
# 1  [Karl-Liebknecht-Str. 13 (Rochstr.), 10178 Berlin, Deutschland]
# 2             [Rosa-Luxemburg-Straße 6, 10178 Berlin, Deutschland]
# 3                    [Alexanderplatz 8, 10178 Berlin, Deutschland]
# 4                [Münzstr. 21 (1. Hof), 10178 Berlin, Deutschland]
# 5                   [Almstadtstr. 9-11, 10119 Berlin, Deutschland]
# 6                          [Rochstr. 2, 10178 Berlin, Deutschland]
# 7                  [Max-Beer-Straße 13, 10119 Berlin, Deutschland]
# 8               [Rosa-Luxemburg-Str. 7, 10178 Berlin, Deutschland]
# 9                       [Rathausstr. 5, 10178 Berlin, Deutschland]
#
#   crossStreet neighborhood                        id
# 0         NaN          NaN  4bb8541f1261d13a118fe898
# 1    Rochstr.        Mitte  5b55e0a9acb00b0039fb45e3
# 2         NaN          NaN  57e908c6498e2af8ac3f326f
# 3         NaN          NaN  588875294745863ba6709dcf
# 4      1. Hof          NaN  54bd1e28498eec46cfc17c24
# 5         NaN          NaN  551706fe498e237bfc874019
# 6         NaN          NaN  4b0d8651f964a520304a23e3
# 7         NaN          NaN  579a410b498e5f7c187c5d91
# 8         NaN          NaN  4adcda88f964a520854921e3
# 9         NaN          NaN  4c28ad7997d00f47212d40ea

# %%
area_map = folium.Map(location=[latitude, longitude], zoom_start=13) #generate map centred around the Conrad Hotel
# add a red circle marker to represent the Alexander platz the center of berlin
folium.CircleMarker([latitude, longitude],radius=10,color='red',popup='coffee shop',fill = True,fill_color = 'red',fill_opacity = 0.6).add_to(area_map)
# add the coffee shop  as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker([lat, lng],radius=5,color='blue',popup=label,fill = True,fill_color='blue',fill_opacity=0.6).add_to(area_map)
# display map
area_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_afd3101f87f34082bf130ef55c2d3eed%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_afd3101f87f34082bf130ef55c2d3eed%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_afd3101f87f34082bf130ef55c2d3eed%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_afd3101f87f34082bf130ef55c2d3eed%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B52.52265601136413%2C13.409790005427109%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20 ...
